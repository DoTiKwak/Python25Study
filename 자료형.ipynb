# %% [markdown]
# <a href="https://colab.research.google.com/github/DoTiKwak/Python25Study/blob/master/%EC%9E%90%EB%A3%8C%ED%98%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 숫자형
# Number타입 : 정수, 실수, 8진수, 16진수, 2진수 등을 표현

a = 123
print(a)

b = 135
print(b)

c = 1.23
print(c)
# Out:
# 123
# 135
# 1.23

# %%
head = "Python"
tail = " is fun !"
head + tail
# Out:
# 'Python is fun !'
